# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from analytics import*

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

sns.set(style="whitegrid")

# Load the dfset
df = pd.read_csv("Performance_Of_Bangladeshi_Students.csv")
df['stu_group'] = df['stu_group'].str.capitalize()
df['location'] = df['location'].str.capitalize()
subjects = ['english', 'math', 'science', 'art_culture']
df['total_score'] = df[subjects].sum(axis=1)
df['average_score'] = df['total_score'] / len(subjects)

# %%
x = analyze_performance_by_demographics(df,subjects)

# %%
analyze_average_achievements(df,subjects,'tutoring', plot=True)

# %%
analyze_studytime_by_demographics(df,'location')

# %%
analyze_location_schooltype(df,'rural')
analyze_location_schooltype(df,'city')
analyze_location_schooltype(df,'urban')

# %%
analyze_extracurricular_influence(df,'age')

# %%
analysis_attendance_vs_performance(df,'age')

# %%
df
# Out:
#         id         full_name  age  gender location  family_size  \
# 0        2        Avi Biswas   16    Male    Urban            6
# 1        3   Taslima Sultana   18  Female    Rural            6
# 2        4  Md Adilur Rahman   15    Male    Rural            4
# 3        5       Saleh Ahmed   16    Male    Rural            6
# 4        6         Din Islam   17    Male    Urban            5
# ...    ...               ...  ...     ...      ...          ...
# 8605  8609      Elina Khanam   17  Female     City            5
# 8606  8610       Sadiq Ghosh   16    Male     City            2
# 8607  8611        Arman Amin   18    Male     City            3
# 8608  8612     Tawhidul Saif   15    Male    Urban            5
# 8609  8613        Naimul Sen   18    Male    Urban            3
#
#      mother_education father_education mother_job father_job  ... attendance  \
# 0                 SSC              HSC         No         No  ...         95
# 1                 SSC              HSC         No        Yes  ...         92
# 2                 SSC              SSC        Yes        Yes  ...         81
# 3                 SSC              SSC        Yes        Yes  ...         90
# 4              Honors          Masters         No        Yes  ...         75
# ...               ...              ...        ...        ...  ...        ...
# 8605              HSC     Non_Educated         No         No  ...         78
# 8606              SSC        Under_SSC         No        Yes  ...         73
# 8607          Diploma              SSC         No         No  ...         51
# 8608           Honors              HSC         No         No  ...         66
# 8609          Diploma        Under_SSC         No         No  ...         88
#
#      extra_curricular_activities english  math science social_science  \
# 0                            Yes      95    98      92             94
# 1                             No      65    71      40             78
# 2                            Yes      64    78      58             86
# 3                            Yes      84    90      85             86
# 4                            Yes      54    70      45             79
# ...                          ...     ...   ...     ...            ...
# 8605                         Yes      81    83      80             84
# 8606                          No      95   100      96             98
# 8607                          No      45    59      41             51
# 8608                         Yes      59    65      60             68
# 8609                         Yes      87    95      96            100
#
#       art_culture stu_group  total_score  average_score
# 0              98   Science          383          95.75
# 1              80  Commerce          256          64.00
# 2              74  Commerce          274          68.50
# 3              88   Science          347          86.75
# 4              76  Commerce          245          61.25
# ...           ...       ...          ...            ...
# 8605           91   Science          335          83.75
# 8606           98   Science          389          97.25
# 8607           69      Arts          214          53.50
# 8608           69      Arts          253          63.25
# 8609           98   Science          376          94.00
#
# [8610 rows x 26 columns]
